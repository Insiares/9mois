# %%
import json
from sqlalchemy import create_engine, MetaData, Table
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import joblib 
import os
import numpy as np
from modules.db import process_table, connect_db
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize

# %%
def connect_db():
    engine = create_engine("mysql+pymysql://root:root@9mois.ownedge.fr:3306/9mois")
    metadata = MetaData()
    return engine, metadata


def process_table(engine, metadata,table_name):
    table = Table(table_name, metadata, autoload_with=engine)
    with engine.connect() as connection:
        result_set = connection.execute(table.select()).fetchall()
    return result_set

def concatenate_row_values(row):
    return ''.join(str(value) for value in row if isinstance(value, str))

def load_stop_words(path):
    with open(path, "r") as file:
        return json.load(file)
    
def tokenizer_stemmer(text):
    stemmer = SnowballStemmer("french")
    tokens = word_tokenize(text, language="french")
    stemmed_tokens = [stemmer.stem(word) for word in tokens]
    return stemmed_tokens

def init_api():
    engine, metadata = connect_db()
    stop_words = load_stop_words("./data/stop_words_french.json") #TODO : clarify path
    tables = ['articles', 'food', 'questions', 'recipes']
    data = {table: process_table(engine, metadata, table) for table in tables}
    # Préparation du vectorisateur TF-IDF

    vectorizers = {table: TfidfVectorizer(tokenizer=tokenizer_stemmer, stop_words=stop_words) for table in tables}

    for table in tables:
        docs = [concatenate_row_values(row) for row in data[table]]
        vectorizers[table].fit_transform(docs)

    #Save the vectorizers

    save_files_path = './ML/'
    for key, vect in vectorizers.items():
        save_path = os.path.join(save_files_path, str(key+'.sav'))
        joblib.dump(vect, save_path)

    #build corpus and export it
    corpus = { }
    for table in tables:
        documents = data[table]
        vectorizer = vectorizers[table]
        corpus[table] = vectorizer.transform([concatenate_row_values(row) for row in documents])

    for key, mat in corpus.items():
        save_path = os.path.join('./data/', str(key))
        np.save(save_path, mat)
    
    return data

def load_vect():
    tables = ['articles', 'food', 'questions', 'recipes']
    base_path = './ML/'
    vect = { table : joblib.load(os.path.join(base_path, str(table+'.sav'))) for table in tables}
    return vect

def load_corpus():
    corpus = { 'articles' : np.load('./data/articles.npy', allow_pickle= True).item(),
               'food' : np.load('./data/food.npy', allow_pickle= True).item(),
                'questions' : np.load('./data/questions.npy', allow_pickle= True).item(),
                 'recipes' : np.load('./data/recipes.npy', allow_pickle= True).item() }
    return corpus

def get_document_id(doc):
    return doc[0]

# Fonction de recherche
def search(query, data, corpus, vectorizers, table_name):
    documents = data[table_name]
    vectorizer = vectorizers[table_name]
    query_vec = vectorizer.transform([query])
    scores = cosine_similarity(query_vec, corpus[table_name]).flatten()
    ranked_scores = sorted([(score, row) for score, row in zip(scores, documents)], reverse=True, key=lambda x: x[0])
    return ranked_scores[:10]  # 10 meilleurs résultats

# %%
data = init_api()
corpus = load_corpus()
vectorizers = load_vect()
tables = ['articles', 'food', 'questions', 'recipes']
# Out:
# c:\Users\Thaz\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
len(test)
# Out:
# 4

# %%
result_set = process_table(engine, metadata, 'recipes')
result_set
# Out:
# [(1, 'Courge rôtie', 55, 'Facile', 'Bon Marché', '/images/recipes/courge_rotie.jpg', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette qui contribue aux **apports en légumes** (1 part = 2 portions de légumes)\n> - Cette recette e ... (251 characters truncated) ... e est **riche en vitamine A**, dont les besoins augmentent pendant la grossesse (surtout au 3e trimestre).\n- Parfaite pour **la saison d’automne** !', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Courge rôtie + pâtes (complètes de préférence) + pois chiches 🌿\n- ... (140 characters truncated) ... 🌿\n- Courge rôtie + riz (complet de préférence) + oeuf dur\n- Courge rôtie + semoule + pois chiches 🌿\n- Courge rôtie + semoule + boeuf haché (5% MG)', "1. Préchauffer le four à 190°C\n2. Couper la courge en 2 et retirer les pépins\n3. Mettre dans un plat allant au four rempli d'un fond d'eau\n4. Quad ... (216 characters truncated) ... e)\n6. Peler les 2 gousses d’ail, les couper en 2 et enlever le germe\n7. Répartir les morceaux d’ail sur le dessus de la courge\n8. Saler et poivrer", '## Ingrédients\n\n- [ ] 1 courge butternut (env. 600g)\n- [ ] 2 c. à soupe d’huile d’olive\n- [ ] 2 gousses d’ail\n- [ ] Quelques branches de persil\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 6, 10, 15, 31, 35)),
#  (2, 'Muffin à la carotte et aux noix', 10, 'Facile', 'Bon Marché', '/images/recipes/Muffins_carottes_noix.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Un petit plaisir à base de **carottes** et de **noix** qui peut être très bien pour une collation de temps ... (150 characters truncated) ... bébé pendant la grossesse et ensuite pour la croissance de l’enfant.\n> - *Un muffin à la carotte ne remplace pas une portion de fruits et légumes* 😉', 10, '', "1. Préchauffer le four à 180°C (th.6)\n2. Eplucher les carottes, les laver puis les râper.\n3. Dans un saladier, fouetter l'œuf, le sucre, le yaourt  ... (309 characters truncated) ... es à muffins aux 2/3 (*ça va gonfler à la cuisson*).\n7. Ajouter 1 ou 2 cerneaux de noix sur le dessus.\n8. Cuire pendant 20 minutes au four à 180°C.", '## Ingrédients\n\n- [ ] 200g de carottes (env. 1 à 2 carottes, selon la taille)\n- [ ] 125g de farine (*semi-complôte ou complète de préférence*)\n-  ... (99 characters truncated) ... n- [ ] 1 oeuf\n- [ ] 50g d’huile d’olive\n- [ ] 1 yaourt\n- [ ] 70g de cerneaux de noix\n- [ ] 1 pincée de sel\n- [ ] 1/2 cuillère à café de cannelle', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 6, 10, 15, 31, 35)),
#  (3, 'Boulghour à la tomate et aux pois chiches', 35, 'Facile', 'Bon Marché', '/images/recipes/Boulghour_tomates_poischiches.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette de **plat complet** avec des **légumes**, des **féculents** et des **légumineuses** !\n> - L’a ... (207 characters truncated) ... ne B3**.\n> - Les **pois chiches** apportent aussi de la **vitamine B9** (une portion c’est environ 15% des apports recommandés pendant la grossesse)', 4, '.', '1. *Passez directement à l’étape 2 si vous utilisez une boîte de tomates pelées* : Laver les tomates et les tremper 2 minutes dans l’eau bouillante p ... (587 characters truncated) ... es)\n8. Saler et poivrer.\n9. Laver les branches de ciboulette, les ciseler et les ajouter au mélange boulghour-tomates-pois chiches avant de servir.', '## Ingrédients\n\n- [ ] 300 g de boulghour cru\n- [ ] 6 tomates pelées (*possible en bocal ou boîte*)\n- [ ] 1 oignon\n- [ ] 250g de pois chiches cuits (*env. une petite boîte*)\n- [ ] 2 c. à soupe d’huile d’olive\n- [ ] Ciboulette\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 7, 1, 17, 23, 22)),
#  (4, 'Galettes de haricots rouges (steak végétarien)', 15, 'Facile', 'Bon Marché', '/images/recipes/Galette_haricots_rouges.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Les **haricots rouges** sont des légumineuses, il est recommandé d’en consommer 2 fois par semaine minimum ... (179 characters truncated) ... la grossesse.\n> - Ces galettes à base de **haricots rouges** sont une alternative végétale au steak haché classique pour un plat ou même un burger !', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Burger : Galette de haricots rouges + pain à burger + [mayonnaise  ... (326 characters truncated) ... erts\n    - Galette de haricots rouges  + semoule + chakchouka poivrons-tomates\n- Salades complètes :\n    - Galette de haricots rouges + roquette +', '1. Si vous utilisez des haricots en boîte, passez directement à l’étape 2\n    1. Rincer environ 250g de haricots rouges et les faire tremper dans l’ ... (687 characters truncated) ...  en 4 galettes. \n7. Faire chauffer une poêle avec 1 cuillère à soupe d’huile d’olive et faire cuire les galettes environ 5-7 minutes de chaque côté.', '## Ingrédients\n\n- [ ] 1 boîte de haricots rouges (500g égouttés) (*possible de les préparer soi-même*)\n- [ ] 1 oignon\n- [ ] 1 bouquet de persil p ... (83 characters truncated) ... ide (*classique ou végétale : riz ou avoine*)\n- [ ] 2 cuillère à soupe d’huile de colza\n- [ ] Paprika (*ou autres épices*)\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 6, 10, 15, 31, 35)),
#  (5, 'Filet de poulet façon basquaise', 40, 'Facile', 'Bon Marché', '/images/recipes/Poulet_basquaise.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette légère qui mélange **poulet et sauce tomate aux poivrons mijotée**.\n> - Les poivrons sont trè ... (230 characters truncated) ... ndés** pour la grossesse en **protéines** et en **vitamine B6** *(qui aide à réduire la fatigue et à la formation des globules rouges dans le sang).*', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Filets de poulet façon basquaise + semoule\n- Filets de poulet faç ... (5 characters truncated) ... squaise + spaghettis complets\n- Filets de poulet façon basquaise + riz complet\n- Filets de poulet façon basquaise + 1 belle tranche de pain complet', '## \n\n1. Couper les filets de poulet\xa0en morceaux. Saler légèrement et saupoudrer de piment d’espelette.\n2. Bien rincer les poivrons et retirer l ... (704 characters truncated) ...  nouveau pendant 10 minutes *(si le mélange accroche au moment de l’ajout du poulet, il est possible d’ajouter un verre d’eau)*\n8. Saler et poivrer.', '## Ingrédients\n\n- [ ] 4 filets de poulet (environ 600g)\n- [ ] 3 poivrons : 1 vert, 1 rouge & 1 jaune (environ 500g)\n- [ ] 400g de pulpe de tomate ... (16 characters truncated) ... ’un pot en verre)\n- [ ] 1 oignon jaune\n- [ ] 2 gousses d’ail\n- [ ] 2 c. à soupe d’huile d’olive\n- [ ] Piment d’espelette\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 6, 10, 15, 31, 35)),
#  (6, 'Pâtes à la courge et aux pois chiches', 25, 'Facile', 'Bon Marché', '/images/recipes/Pates_courges_poischiches.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette **vegan,** très facile à préparer et économique !\n> - Les **pois chiches** sont une bonne sou ... (267 characters truncated) ... uvre **la moitié des apports recommandés en fibres pendant la grossesse**.\n> - Parfaite pour un **plat complet et équilibré** pour **le déjeuner** !', 4, '.', '1. Peler la courge et la couper en dés (*s’il s’agit d’un potimarron, il est possible de laisser la peau, à condition de bien le laver en le rinçant  ... (653 characters truncated) ... mmandé de ne pas consommer de fromage râpé industriel, mais de râper soi-même son fromage.*\n10. Ajouter un peu de parmesan râpé sur chaque assiette.', '## Ingrédients\n\n- [ ] 400 g de fusillis crus (complets si possible)\n- [ ] 400 g de potiron\n- [ ] 400 à 500 g de pois chiches cuits (l’équivalent dune grosse boîte/bocal égouttée)\n- [ ] *Option* : 60g de parmesan\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 7, 1, 17, 24, 44)),
#  (7, 'Maquereaux panés aux amandes', 60, 'Facile', 'Bon Marché', '/images/recipes/Maquereaux_panes_amandes.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette qui contribue à la **consommation hebdomadaire de poisson gras**.\n> - Cette recette est notam ... (256 characters truncated) ... uereau est un des poissons gras **les moins coûteux** ! Si on a un petit budget, on peut privilégier les filets en conserve (au naturel et sans vin).', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Maquereaux panés aux amandes + riz (complet de préférence) + sauce ... (146 characters truncated) ...  (aux noix)\n- Maquereaux panés aux amandes + brocolis sautés + pain complet ou aux graines\n- Maquereaux panés aux amandes + quinoa + épinards cuits', '1. Préchauffer le four à 180°C\n2. Laver les filets de maquereaux et les sécher sur du papier absorbant\n3. Battre l’oeuf dans un bol\n4. Mettre la p ... (334 characters truncated) ... poser dans un plat allant au four\n7. Arroser de 4 c. à soupe d’huile d’olive\n8. Saler et Poivrer\n9. Faire cuire au four à 180°C pendant 20 minutes', '## Ingrédients\n\n- [ ] 8 filets de maquereau (env. 50g l’un) ou 4 boîtes de filets de maquereau au naturel\n- [ ] 1 oeuf\n- [ ] 50 g de farine\n- [  ... (28 characters truncated) ... - [ ] 4 c. à soupe d’huile d’olive\n- [ ] Sel\n- [ ] Poivre\n- [ ] Option : curry, paprika, cumin, persil, ou autres épices et herbes selon vos goûts', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 6, 10, 15, 31, 35)),
#  (8, 'Pâtes aux filets de maquereaux et tomates', 15, 'Facile', 'Bon Marché', '/images/recipes/Pates_filets_maquereau.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette équilibrée, très facile à préparer et économique !\n> - Le **maquereau** est un des poissons l ... (201 characters truncated) ... ouvre **un tiers des apports recommandés en fibres pendant la grossesse**.\n> - Parfaite pour un **plat complet et équilibré** pour **le déjeuner** !', 4, '.', '1. Faire chauffer une casserole d’eau salée jusqu’à ébullition.\n2. Dès que l’eau bout, ajouter les spaghettis et faire cuire pendant la durée indiqu ... (272 characters truncated) ... ge, râper le gruyère sur les pâtes (*enceinte, il est recommandé de ne pas consommer de fromage râpé industriel, mais de râper soi-même son fromage*)', '## Ingrédients\n\n- [ ] 400g de spaghettis crus (complets ou semi-complets si possible)\n- [ ] 2 boîtes (env. 200g) de filets de maquereau au naturel\n- [ ] 400g de coulis de tomates en bocal ou maison\n- [ ] 60g de gruyère\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 7, 1, 17, 25, 39)),
#  (9, 'Velouté de panais aux noisettes', 40, 'Facile', 'Bon Marché', '/images/recipes/Veloute_panais_noisettes.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette parfaite pour une entrée qui allie **légumes et fruits secs.**\n> - Le panais et les noisettes ... (74 characters truncated) ... é qu’une portion de ce velouté contient **15% des apports recommandés en vitamine B9 pour la grossesse.**\n> - Parfaite pour une **entrée d’hiver** !', 4, '.', '1. Laver, éplucher et coupe le panais en dés.\n2. Emincer l’oignon.\n3. Faire chauffer l’huile d’olive dans une grosse casserole et ajouter l’oignon. ... (601 characters truncated) ... n)\n12. Laisser les noisettes refroidir légèrement et les concasser.\n13. Parsemer les noisettes grillées et quelques chips de panais sur le velouté.', '## Ingrédients\n\n- [ ] 600g de panais (env. 3 panais moyens)\n- [ ] 10cl de crème semi-épaisse (ou crème de riz ou d’amande pour une version végétal ... (130 characters truncated) ... e d’olive\n- [ ] 60g de noisettes\n- [ ] Chips de panais\n- [ ] Option: 1 cuillère à soupe de pâte de noisettes (non sucrée)\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 35), datetime.datetime(2023, 7, 1, 17, 26, 18)),
#  (10, 'Flan à la carotte et à la coriandre', 45, 'Facile', 'Bon Marché', '/images/recipes/Flan_carotte_coriandre.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette très facile à préparer pour consommer des **légumes.**\n> - La carotte est **riche en bêta-carotène (vitamine A),** une portion de ce flan à la carotte couvre **110% des apports recommandés en vitamine A pour la grossesse.**', 4, '- Une tranche de pain complet et de la salade (roquette, laitue, mâche)', '1. Préchauffer le four à 180°C.\n2. Eplucher les carottes, les laver, les couper en 4 et faire cuire à la vapeur pendant 10 minutes.\n3. Pendant la c ... (448 characters truncated) ... s ramequins allant au four (ou moule à muffins).\n9. Cuire pendant 30 minutes au four.\n\n*Ce flan peut se déguster chaud ou froid selon vos envies.*', '## Ingrédients\n\n- [ ] 600g de carottes\n- [ ] 2 oeufs\n- [ ] 10 cl de crème liquide (*possible de remplacer par du lait de coco ou crème d’amande ou riz*)\n- [ ] 50g de comté (râpé maison)\n- [ ] Coriandre fraîche (*à remplacer par du persil si on déteste la coriandre*)\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 7, 1, 17, 27, 29)),
#  (11, 'Omelette aux brocolis', 20, 'Facile', 'Bon Marché', '/images/recipes/Omelette_brocoli.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette très facile avec peu d’ingrédients qui allie **légumes et protéines animales.**\n> - Le brocol ... (22 characters truncated) ... es plus **riches en vitamine C,** une portion de cette omelette aux brocolis couvre **100% des apports recommandés en vitamine C pour la grossesse.**', 2, '- Une tranche de pain complet ou aux noix', '1. Laver les brocolis. Retirer les feuilles (s’il y en a) et couper la tige pour ne garder que les fleurons.\n2. Chauffer une cuillère à soupe d’huil ... (275 characters truncated) ... ta\n6. Cuire environ 3 minutes sur une face \n7. Retourner l’omelette et faire cuire 2 minutes sur la deuxième face.\n8. Couper en 2 et servir chaud.', '## Ingrédients\n\n- [ ] 300g de brocolis crus (frais ou surgelés)\n- [ ] 4 oeufs\n- [ ] 1 cuillère à soupe d’huile d’olive\n- [ ] Option: 60g de feta\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 7, 1, 17, 28, 19)),
#  (12, 'Salade de quinoa, brocoli, radis rose et oeuf dur', 35, 'Facile', 'Bon Marché', '/images/recipes/Salade_quinoa_brocoli_radis_oeufdur.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette de **salade complète** **végétarienne** !\n> - Les **ingrédients (quinoa, brocoli, radis, oeuf ... (160 characters truncated) ... e recette couvre **70% des apports recommandés en vitamine B9 pendant la grossesse.**\n> - Parfaite une salade à préparer pour le **repas de midi** !', 4, '.', '1. Préparer le quinoa :\n    1. Rincer le quinoa sous l’eau (pour enlever le goût amer).\n    2. Faire bouillir env. 600 mL d’eau salée dans une cass ... (946 characters truncated) ... t 6 cuillères à soupe de levure alimentaire (maltée)\n    3. Saler et poivrer.\n    4. Mélanger puis ajouter les oeufs dur coupés en 2 sur le dessus.', '## Ingrédients\n\n- [ ] 320 g de quinoa cru\n- [ ] 600g de brocoli cru\n- [ ] Une botte de radis (env. 250g sans les feuilles)\n- [ ] 6 oeufs\n- [ ] 6 c. à soupe de levure alimentaire (maltée, diététique, ou de bière)\n- [ ] 4 c. à soupe d’huile d’olive\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 7, 1, 17, 29, 11)),
#  (13, 'Socca, épinards et graines de tournesol', 30, 'Facile', 'Bon Marché', '/images/recipes/Socca_epinards_tournesol.png', '> ***L’avis 9 mois à croquer :***\n> \n> - La socca est une **recette niçoise** : c’est une galette épaisse à base de farine de pois chiches. Parfait ... (191 characters truncated) ... grossesse, et le développement de bébé.\n> - Une portion de cette recette couvre **70% des apports recommandés en vitamine B9 pendant la grossesse.**', 4, '.', '1. Préparer la pâte pour la socca :\n    1. Mettre la farine de pois chiches dans un saladier.\n    2. Ajouter progressivement l’eau froide en fouett ... (1015 characters truncated) ...  galette de socca dans une assiette, ajouter 150g d’épinards cuits. Parsemer d’une cuillère de graines de tournesol.\n5. Saler légèrement et poivrer.', '## Ingrédients\n\n- [ ] 200 g de farine de pois chiches\n- [ ] 400ml d’eau froide\n- [ ] 600g d’épinards cuits (soit surgelés, soit 2kg d’épinards cr ... (4 characters truncated) ...  cuire)\n- [ ] 6 c. à soupe de graines de tournesol\n- [ ] 3 c. à soupe d’huile d’olive\n- [ ] 1/2 c. à café d’ail en poudre\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 7, 1, 17, 29, 52)),
#  (14, 'Lentilles à la marocaine', 60, 'Facile', 'Bon Marché', '/images/recipes/lentilles_marocaine.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Les **lentilles** sont une bonne source de **protéines végétales** et de **fibres**. Une portion de cette  ... (237 characters truncated) ... les femmes enceintes manquent souvent. Une portion de cette recette apporte environ **25% des apports recommandés pour le fer pendant la grossesse**.', 4, '- Une tranche de pain complet ou aux graines', '1. Porter une casserole d’eau à ébullition.\n2. Rincer les lentilles en les passant 2 fois sous l’eau fraîche et les mettre à cuire pendant 15 minute ... (762 characters truncated) ... mijoter le tout à feu doux pendant 20\xa0minutes.\n14. Laver les branches de persil et les hacher avant de les ajouter aux lentilles avant de servir.', '## Ingrédients\n\n- [ ] 250g de lentilles vertes\n- [ ] 3 carottes\n- [ ] 2 branches de céleri\n- [ ] 3 gousses d’ail\n- [ ] 1 oignon jaune\n- [ ] 14 ... (75 characters truncated) ... illère à café de paprika, 1/2 cuillère à café de cannelle, 1 pincée de piment, 1 pincée de sel et 1 pincée de poivre noir\n- [ ] 3 branches de persil', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 7, 1, 17, 30, 47)),
#  (15, 'Salade de lentilles, betteraves et poire, vinaigrettes aux agrumes', 35, 'Facile', 'Bon Marché', '/images/recipes/Salade_lentilles_poires_betteraves.png', '> ***L’avis 9 mois à croquer :***\n> \n> - La **mâche** est une des variétés de salades qui contient le plus de **vitamines** (notamment **A, B9 et K ... (320 characters truncated) ... ur le fer pendant la grossesse**.\n> - Cette recette, accompagnée d’une tranche de pain complet, est parfaite pour un **plat complet et équilibré** !', 4, '', '1. Si lentilles sèches : \n    1. Porter une casserole d’eau à ébullition.\n    2. Rincer les lentilles en les passant 2 fois sous l’eau fraîche et l ... (700 characters truncated) ... he, les lentilles cuites, les dés de betterave, les lamelles de poire, les cerneaux de noix.\n6. Ajouter la vinaigrette aux agrumes et bien mélanger.', '## Ingrédients\n\n- [ ] 200g de lentilles vertes (*ou une boîte de 400g de lentilles en conserve*)\n- [ ] 200g de mâche\n- [ ] 1 betterave cuite\n- [ ... (71 characters truncated) ... s : 10 cl d’huile d’olive, le jus d’1/2 citron, le jus d’une orange, zestes d’orange (si bio), 1 cuillère à soupe de vinaigre balsamique, sel, poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (16, 'Sorbet kiwi aux amandes', 380, 'Facile', 'Bon Marché', '/images/recipes/Sorbet_kiwi_amandes.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Ce sorbet est très fruité et **riche en vitamine C** (2 boules couvrent 80% des apports recommandés en vit ... (19 characters truncated) ... ssesse).\n> - Agrémenté d’amandes effilées ou d’éclats de biscuits, il peut devenir un **dessert frais**, **parfait pour terminer un repas copieux**.', 4, '.', '1. Dans une casserole, faire un sirop en faisant bouillir le sucre et l’eau (le mélange ne doit pas colorer, il doit simplement épaissir un peu). Lai ... (836 characters truncated) ...  colorent.\n9. Faire des boules de sorbet, les disposer dans les coques de peau de kiwi (ou dans des coupes) et parsemer d’amandes effilées grillées.', '## Ingrédients\n\n- [ ] 1kg de kiwis (environ 10-12)\n- [ ] 100g de sucre\n- [ ] 300ml d’eau\n- [ ] 50g d’amandes effilées', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 7, 1, 17, 31, 26)),
#  (17, 'Truffes au chocolat biscuitées', 390, 'Facile', 'Bon Marché', '/images/recipes/truffes_chocolat_biscuitees.jpg', '> ***L’avis 9 mois à croquer :***\n> \n> - Les truffes au chocolat maison sont **bien moins sucrées** que celles qu’on retrouve dans le commerce.\n>  ... (147 characters truncated) ... co, du cacao en poudre, des vermicelles selon les goûts)\n> - De quoi se régaler avec **des gourmandises maison** pour les fêtes de fin d’année ****!', 4, '', '1. Couper le chocolat (250g) en petits morceaux dans un saladier \n2. Faire bouillir la crème dans une casserole.\n3. Verser la crème chaude en 3 foi ... (941 characters truncated) ... tion jusqu’à ce que toutes les truffes soient enrobées de chocolat.\n11. Conserver au réfrigérateur (5 jours) et sortir 30 minutes avant de déguster.', '## Ingrédients\n\n- [ ] 250g de chocolat noir à 70%\n- [ ] 20cl de crème liquide\n- [ ] Enrobage : 150g de chocolat noir à 70% + brisures de biscuits + cure-dents', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (18, 'Trifle kiwi, muesli et fromage blanc', 10, 'Facile', 'Bon Marché', '/images/recipes/Trifle_kiwi_fromageblanc_muesli.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Cette recette peut être consommée pour un **petit-déjeuner équilibré,** elle comporte un **fruit** (le kiw ... (343 characters truncated) ...  la recette sont données pour une **portion au petit-déjeuner**. Dans le cas d’un dessert, on peut diviser les quantités par deux pour mieux digérer.', 1, '', '- Version pour une jolie présentation :\n    1. Mettre 2 cuillères à soupe de muesli au fond d’un verre. \n    2. Couper un kiwi en tranches et dispo ... (230 characters truncated) ... rer :\n    1. Couper les kiwis en dés\n    2. Dans un verre, alterner une couche de muesli, une couche de fromage blanc et une couche de dés de kiwi.', '## Ingrédients\n\n- [ ] 2 kiwis (*1 pour les petites faims*)\n- [ ] 150g de fromage blanc (*100g pour les petites faims*)\n- [ ] 40g de muesli aux noix (*25g pour les petites faims*)', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (19, 'Cocktail menthe, gingembre, citron (sans alcool)', 5, 'Facile', 'Bon Marché', '/images/recipes/Cocktail_menthe_gingembre_citron_ssalcool.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Ce **cocktail sans alcool** est très rafraîchissant et **moins sucré** que les boissons retrouvées dans le ... (163 characters truncated) ... sées, vomissements et remontées acides)\n> - Parfait pour un **apéritif estival rafraîchissant** ou pour trinquer lors des fêtes de fin d’année ****!', 4, '', '1. Eplucher le gingembre et le couper en morceau\n2. Ecraser le gingembre avec un pilon au fond d’un bol\n3. Bien laver la menthe, l’ajouter au ginge ... (352 characters truncated) ... le) et mettre au frais pendant 30 minutes\n9. Servir frais dans des verres décorés avec quelques feuilles de menthe et des rondelles de citron frais.', '## Ingrédients\n\n- [ ] 1L d’eau pétillante (ou plate si l’eau pétillante augmente vos remontées acides\n- [ ] 5 cm de racine de gingembre\n- [ ] 3 branches de menthe fraîche (+ 1 branche pour la déco)\n- [ ] 2 citrons jaunes (+ 1 pour la déco)\n- [ ] Optionnel: 3 cuillères à soupe de cassonade', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (20, 'Eau citronnée et mentholée', 5, 'Facile', 'Bon Marché', '/images/recipes/eau_mentholee_citronnee.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Les besoins en eau sont augmentés pendant la grossesse. Il est recommandé de boire **1,5 à 2 litres d’eau  ... (246 characters truncated) ... au citronnée dans une gourde d’un litre **la veille,** la conserver au réfrigérateur et **la consommer petit à petit** dans la journée du lendemain !', 4, '', '1. Bien laver la menthe et prélever les feuilles.\n2. Laver le citron.\n3. Couper le citron en 2. Si le citron est bio, en conserver 2 rondelles. \n4 ... (297 characters truncated) ... davantage les arômes dans l’eau*).\n8. Si le citron est bio, ajouter les 2 rondelles de citron.\n9. Conserver au réfrigérateur et boire dans les 24h.', '## Ingrédients\n\n- [ ] 1L d’eau (robinet ou bouteille selon vos goûts)\n- [ ] 2 branches de menthe fraîche (bio de préférence)\n- [ ] 1 citron jaune (bio de préférence)', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (21, 'Infusion glaçée pêche, orange, romarin', 365, 'Facile', 'Bon Marché', '/images/recipes/The_glace_romarin_peche.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Les besoins en eau sont augmentés pendant la grossesse. Il est recommandé de boire **1,5 à 2 litres d’eau  ... (211 characters truncated) ...  Vous pouvez **préparer** cette tisane dans une carafe ou dans une gourde et la conserver au réfrigérateur ! Pensez à **la consommer** dans les 24h !', 4, '', '1. Bien laver les branches de romarin et l’orange.\n2. Couper l’orange en 2. Couper des rondelles dans la première moitié et conserver l’autre moitié ... (276 characters truncated) ... marin.\n6. Laisser infuser 5 minutes puis retirer les sachets d’infusion.\n7. Ajouter les glaçons.\n8. Placer au réfrigérateur et boire dans les 24h.', '## Ingrédients\n\n- [ ] 1L d’eau (robinet ou bouteille selon vos goûts)\n- [ ] 3 sachets d’infusion/tisane à la pêche\n- [ ] 2 branches de romarin (bio de préférence)\n- [ ] 1/2 orange (bio de préférence)\n- [ ] Une vingtaine de glaçons', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (22, 'Navets glaçés au miel', 50, 'Facile', 'Bon Marché', '/images/recipes/Navets_glaces_miel.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette qui contribue aux **apports en légumes** (1 part = 1 portions de légumes)\n> - Parfaite en **accompagnement d’un plat de volaille** !', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Navets glacés au miel + semoule + Roulés de dinde aux pistaches et abricots secs\n- Navets glacés au miel + semoule + Pois chiches  🌿\n- Navets glacés au miel + riz + canard laqué (bien cuit)', "1. Nettoyer et éplucher les navets\n2. Dans une poêle chaude, faire fondre le beurre.\n3. Ajouter les navets et le faire dorer 5 minutes.\n4. Ajouter ... (509 characters truncated) ...  pour caraméliser les navets en remuant pour pas qu’ils n’accrochent.\n9. Arrêter la cuisson lorsque les navets sont colorés. \n10. Saler et poivrer.", '## Ingrédients\n\n- [ ] 16 petits navets\n- [ ] 30g de beurre\n- [ ] 1 c. à soupe de miel\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (23, "Salade d'endives, pommes, noix - vinaigrette à l'huile de noix", 15, 'Facile', 'Assez Cher', '/images/recipes/Salade_endive_pommes_noix.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette contribue aux **apports en légumes** (1 part = 1 portions de légumes)\n> - Une portion de cett ... (118 characters truncated) ... ale** (aussi appelé ALA, acide alpha-linolénique) grâce aux noix et à la vinaigrette à l’huile de noix.\n> - Parfaite pour **une entrée hivernale** !', 4, '.', '1. Laver les endives, retirer la base et les couper en tronçons.\n2. Peler la pomme et la couper en dés.\n3. Laver le persil et le ciseler.\n4. Conca ... (376 characters truncated) ... eant bien.\n    3. Lorsque l’ensemble est bien mélangé, ajouter le poivre.\n7. Ajouter la vinaigrette à l’huile de noix dans le saladier et mélanger.', '## Ingrédients\n\n- [ ] 4 endives\n- [ ] 1 pomme\n- [ ] 12 noix (ou 24 cerneaux de noix décortiqués)\n- [ ] 1 branche de persil ciselée (ou persil dé ... (91 characters truncated) ... de noix\n- [ ] 1 cuillère à soupe de vinaigre de cidre (ou balsamique ou de noix, selon vos goûts)\n- [ ] 1 cuillère à café de moutarde\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 7, 1, 17, 52, 26)),
#  (24, 'Roulés de dinde aux pistaches et aux abricots secs', 35, 'Facile', 'Coût Moyen', '/images/recipes/Roules_dinde_pistaches_abricots.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette gourmande qui mélange **volaille, fruits secs et fruits à coques**.\n> - L’escalope de dinde e ... (82 characters truncated) ... grossesse. Le mélange pistache-abricots secs ajoute des **fibres et du potassium**.\n> - Parfaite alliance sucrée-salée pour **les repas de fêtes** !', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Roulés de dinde aux pistaches et abricots secs + semoule + carotte ... (98 characters truncated) ... dinde aux pistaches et abricots secs + pommes de terre au four + salade verte\n- Roulés de dinde aux pistaches et abricots secs + purée de potimarron', '1. Concasser les pistaches grossièrement et couper les abricots secs en dés. Mélanger.\n2. Mettre les escalopes entre 2 feuilles de papier cuisson et ... (366 characters truncated) ... le beurre, puis ajouter le sucre pour faire un caramel.\n9. Ajouter les escalopes roulées dans la poêle jusqu’à ce qu’elles soient bien caramélisées.', '## Ingrédients\n\n- [ ] 4 escalopes de dinde\n- [ ] 60g de pistaches décortiquées\n- [ ] 60g d’abricots secs\n- [ ] 100g de Carré Frais ou équivalent (soit 4 carrés)\n- [ ] 50g de beurre\n- [ ] 2 c. à soupe de sucre\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (25, "Mayonnaise à l'huile de colza (sans oeuf)", 5, 'Facile', 'Bon Marché', '/images/recipes/Mayonnaise_colza_sans_oeufs.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Pendant la grossesse, il est recommandé de **ne pas consommer des préparations qui contiennent des oeufs c ... (119 characters truncated) ... rce qui contiennent beaucoup d’additifs.\n> - L’utilisation de l’**huile de colza** permet d’augmenter l**es apports en oméga 3 d’origine végétale**.', 4, '', '1. Dans un récipient haut (type verre), mettre d’abord le lait demi-écrémé puis l’huile de colza (il doit y avoir 2 couches distinctes)\n2. Avec un m ... (173 characters truncated) ... de sel (pas beaucoup, la moutarde est déjà très salée).\n4. Mixer à nouveau quelques secondes jusqu’à ce que la texture soit plus ferme et onctueuse.', '## Ingrédients\n\n- [ ] 50 ml de lait demi-écrémé\n- [ ] 120 ml d’huile de colza\n- [ ] 1 cuillère à café de moutarde\n- [ ] 1 cuillère à café de jus de citron\n- [ ] Sel\n- [ ] Poivre\n- [ ] *Option pour une mayonnaise originale* : Curry, curcuma, ail, cumin, etc. (selon vos goûts)', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (26, 'Colin en papillote', 20, 'Facile', 'Bon Marché', '/images/recipes/Colin_papillotte.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette qui contribue à la **consommation hebdomadaire de poisson maigre**.\n> - Cette recette est ric ... (211 characters truncated) ...  cours des premiers mois.\n> - Le **colin** est un des poissons **les moins coûteux** ! Si on a un petit budget, on peut le trouver surgelé en filet.', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Colin en papillote + riz (complet de préférence) + courgettes saut ... (93 characters truncated) ... ote + semoule + chakchouka poivrons-tomates\n- Colin en papillote + semoule + tomate à la provençale\n- Colin en papillote + spaghetti + salade verte', "1. Préchauffer le four à 180°C\n2. Couper 4 morceaux de papier cuisson (longueur: taille du rouleau / largeur: 3 fois celle du filet de colin)\n3. Dé ... (515 characters truncated) ... ne entaille au couteau sur le dessus\n11. Ajouter un peu d'eau et un filet de citron dans le plat\n12. Faire cuire au four à 180°C pendant 15 minutes", '## Ingrédients\n\n- [ ] 4 filets de colin (env. 100g l’un)\n- [ ] 1 citron\n- [ ] 4 c. à soupe d’huile d’olive\n- [ ] Quelques branches de persil\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (27, 'Cabillaud rôti au fenouil et curry', 40, 'Facile', 'Bon Marché', '/images/recipes/Cabillaud_roti_fenouil_curry.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette qui contribue à la **consommation hebdomadaire de poisson maigre**.\n> - Cette recette est ric ... (211 characters truncated) ...  cours des premiers mois.\n> - Le **colin** est un des poissons **les moins coûteux** ! Si on a un petit budget, on peut le trouver surgelé en filet.', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Cabillaud rôti au fenouil et curry + riz (complet de préférence)\n- Cabillaud rôti au fenouil et curry + pain complet ou aux noix\n- Cabillaud rôti au fenouil et curry + tagliatelles', '1. Préchauffer le four à 200°C.\n2. Laver les bulbes de fenouil. Retirer la base et les branches et couper les bulles en tranches d’environ 1 cm d’ép ... (446 characters truncated) ... r.\n7. Faire cuire au four pendant 15 minutes minimum (le poisson doit être bien cuit).\n8. Servir avec une rondelle de citron vert sur chaque filet.', '## Ingrédients\n\n- [ ] 4 filets de cabillaud (env. 150g l’un)\n- [ ] 4 bulbes de fenouil\n- [ ] 1 citron vert\n- [ ] 4 c. à soupe d’huile d’olive\n- [ ] Curry\n- [ ] Baies Roses\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (28, 'Brochettes de cabillaud sauce kiwi', 30, 'Facile', 'Coût Moyen', '/images/recipes/brochette_cabillaud_sauce_kiwi.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette qui contribue à la **consommation hebdomadaire de poisson blanc** et qui apporte **des vitamin ... (307 characters truncated) ... aud** peut être remplacé par d’autres poissons blanc comme le **colin moins coûteux** ! Si on a un petit budget, on peut le trouver surgelé en filet.', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Brochettes de cabillaud sauce kiwi + riz (complet de préférence)\n ... (29 characters truncated) ... ce kiwi + salade + pain (complet de préférence)\n- Brochettes de cabillaud sauce kiwi + tagliatelles\n- Brochettes de cabillaud sauce kiwi + boulgour', '1. Préchauffer le four à 200°C.\n2. Couper le dos de cabillaud en petits dés (environ 2 cm de large, ce qui fait environ la moitié d’un kiwi). \n3. E ... (487 characters truncated) ...  demi-citron (vert).\n    2. Saler et poivrer.\n8. Servir les brochettes de cabillaud arrosées de la sauce kiwi avec quelques tranches de kiwi frais.', '## Ingrédients\n\n- [ ] 600g de dos de cabillaud (*ou filets de colin*)\n- [ ] 4 cuillère à soupe de graines de sésame\n- [ ] 5 kiwis\n- [ ] 3 c. à soupe d’huile d’olive\n- [ ] 1/2 citron (*vert pour un goût plus acidulé*)\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 6, 10, 15, 31, 36)),
#  (29, 'Blinis maison aux crevettes cuites et fromage frais', 40, 'Facile', 'Bon Marché', '/images/recipes/Blinis_fromagefrais_crevettes.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Les **blinis maison** sont très faciles à réaliser et contiennent à peine 5 ingrédients (contre 10 à 12 po ... (290 characters truncated) ... ique festif, mais **beaucoup d’options de garnitures sont possibles** selon vos goûts (crudités bien lavées et viandes, poissons, oeufs bien cuits !)', 4, '.', '1. Dans un saladier, mélanger au fouet un yaourt, un pot de yaourt de farine, un demi-sachet de levure chimique et 1 oeuf. \n2. Laisser la pâte repos ... (874 characters truncated) ... ue blini avec une cuillère de préparation au fromage frais. Ajouter une crevette cuite. \n10. Saler, poivrer et parsemer de quelques herbes fraîches.', '## Ingrédients\n\n**Pour les blinis :**\n\n- [ ] 1 yaourt\n- [ ] 1 pot de yaourt de farine (complète ou semi-complète de préférence)\n- [ ] 1 oeuf\n- ... (219 characters truncated) ... ] 1/2 citron pressé\n- [ ] Herbes fraîches (persil, ciboulette, aneth selon vos goûts)\n- [ ] 100g de crevettes décortiquées\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 36), datetime.datetime(2023, 7, 1, 18, 0, 35)),
#  (30, 'Salade marocaine tomates pois chiches cumin persil', 5, 'Facile', 'Bon Marché', '/images/recipes/Salade_poischiches_tomates_persil.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Une salade aux accents méditerranéens avec du cumin, des **pois chiches** et des **tomates**, consommez-la ... (169 characters truncated) ... e, sélénium, et vitamines B3, B6, B9 et C,** dont les apports sont essentiels ****pendant la grossesse.\n> - Une salade fraîche parfaite pour l’été !', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Salade marocaine + 1 belle tranche de pain (complet de préférence)\n- Salade marocaine + semoule', '1. Egoutter les pois chiches.\n2. Bien laver les tomates et le persil.\n3. Couper les tomates en tranches ou en cubes. \n4. Eplucher l’oignon, le cou ... (130 characters truncated) ... 7. Ajouter le jus d’un citron, 3 cuillères à soupe d’huile d’olive, 1 cuillère à café de cumin en poudre. \n8. Saler légèrement et poivrer. Mélanger.', '## Ingrédients\n\n- [ ] 400g de tomates (environ 3)\n- [ ] 500g de pois chiches (environ 1 grosse boîte) (*possible de les préparer soi-même*)\n- [ ] ... (16 characters truncated) ...  ] 3 c. à soupe d’huile d’olive\n- [ ] Jus d’un citron\n- [ ] 1 bouquet de persil plat\n- [ ] 1 c. à café de cumin en poudre\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 37), datetime.datetime(2023, 6, 10, 15, 31, 37)),
#  (31, 'Coupe de fraises chocolat et fromage blanc', 5, 'Facile', 'Coût Moyen', '/images/recipes/Fraises_fromageblanc_chocolat.png', '> ***L’avis 9 mois à croquer :***\n> \n> - Cette recette permet de consommer une **portion de fruits** et un produit laitier dans un **dessert gourma ... (291 characters truncated) ... n> - Une recette parfaite pour le printemps et le début de l’été. En hiver, les fraises peuvent être remplacées par des **kiwis** ou des **bananes**.', 4, '', '1. Casser le chocolat en morceaux et le faire fondre (micro-ondes ou bain marie)\n2. Bien laver les fraises, les équetter et les couper en 2. Mettre  ... (79 characters truncated) ... ) de fromage blanc par coupe. Ajouter quelques fraises sur le dessus.\n4. Répartir le chocolat fondu sur les coupes.\n5. Parsemer d’amandes effilées.', '## Ingrédients\n\n- [ ] 500g de fraises\n- [ ] 100g de chocolat noir à 70%\n- [ ] 400g de fromage blanc (*soit 4 pots*)\n- [ ] 50g d’amandes effilées (*soit 2 poignées*)', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 37), datetime.datetime(2023, 6, 10, 15, 31, 37)),
#  (32, 'Brick courgettes fromage frais persil', 35, 'Intermédiaire', 'Bon Marché', '/images/recipes/Brick_courgettes_fromage.png', '> ***L’avis 9 mois à croquer :***\n> \n> - **2 bricks** contiennent l’équivalent de **2 portions de légumes**.\n> - Le fromage frais ajoute des **pro ... (183 characters truncated) ... ver, vous pouvez remplacer les courgettes par des épinards. Si vous n’avez pas le temps de cuisiner, vous pouvez les prendre surgelés ou en conserve.', 5, '.', "1. Bien laver et éplucher les courgettes. Les couper en rondelles.\n2. Faites chauffer 2 cuillères à soupe d’huile d’olive dans une poêle. Faire reve ... (731 characters truncated) ...  une poêle avec 1 c. à soupe d’huile.\n8. Cuire les bricks 3 à 4 minutes sur chaque face (jusqu'à ce qu’elles soient dorées).\n9. Parsemer de sésame.", '## Ingrédients\n\n- [ ] 10 feuilles de brick (1 paquet)\n- [ ] 1 kg de courgettes\n- [ ] 200g (1 barquette) de fromage frais (Saint-Morêt, Carré frai ... (27 characters truncated) ... e d’huile d’olive\n- [ ] 2 branches de persil frais (ou 2 c.à café de persil séché)\n- [ ] 2 c. à soupe de graines de sésame\n- [ ] Sel\n- [ ] Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 37), datetime.datetime(2023, 7, 1, 18, 1, 54)),
#  (33, 'Soupe à la courge et aux lentilles', 60, 'Facile', 'Bon Marché', '/images/recipes/Soupe_courge_lentilles.jpg', '> ***L’avis 9 mois à croquer :***\n> \n> - Une recette qui associe les **légumes**  et les **légumineuses**\n> - Cette recette est **riche en protéin ... (76 characters truncated) ... est **riche en vitamine A**, dont les besoins augmentent pendant la grossesse (surtout au 3e trimestre).\n> - Parfaite pour **la saison d’automne** !', 4, '*Liste non-exhaustive (de nouvelles idées viendront s’ajouter avec le temps)*\n\n- Soupe à la courge et aux lentilles + 1 tranche de pain complet ou  ... (9 characters truncated) ... 🌿\n- Soupe à la courge et aux lentilles + 1 tranche de pain aux noix 🌿\n- Soupe à la courge et aux lentilles + comté (à râper soi-même dans la soupe)', "1. Peler puis hacher les gousses d’ail \n2. Mettre 2 cuillères à soupe d’huile d’olive dans une grande casserole (ou un fait-tout)\n3. Lorsque l’huil ... (1048 characters truncated) ... d’eau)\n12. Verser dans un bol (pas à ras-bord, il faut de la place pour les lentilles)\n13. Ajouter 6 cuillères à soupe de lentilles dans chaque bol", '## Ingrédients\n\n- [ ]  1 courge butternut ou autres (env. 600g)\n- [ ]  120g de lentilles vertes sèches (ou 1 boîte de lentilles cuites)\n- [ ]  2 c. à soupe d’huile d’olive\n- [ ]  2 gousses d’ail\n- [ ]  1 c. à café de curry\n- [ ]  Sel\n- [ ]  Poivre', 0, datetime.date(2023, 6, 10), datetime.datetime(2023, 6, 10, 15, 31, 37), datetime.datetime(2023, 6, 10, 15, 31, 37)),
#  (35, 'Tarte tomate, pesto, chèvre', 50, 'Facile', 'Bon Marché', '/images/recipes/Tarte_tomates_pesto.png', "***L'avis 9 mois à croquer :***\n- Une recette plaisir, rapide et pratique pour l’été, à consommer avec une salade verte.\n- Les atouts nutritionnels ... (195 characters truncated) ... souhaitez une recette moins grasse, vous pouvez remplacer la pâte à tarte par des tranches de pain de campagne et transformer cette tarte en toasts !", 6, '- Une salade verte', '1. Préchauffer le four à 180°C (th.6)\r\n2. Etaler la pâte dans un plat à tarte. La piquer avec une fourchette.\r\n3. Etaler la sauce pesto sur le fo ... (508 characters truncated) ... te cuite si nécessaire)\r\n8. Cuire environ 40 minutes à 180°C.\r\n9. Servir une part (chaude ou froide selon vos préférences) avec une salade verte.', '**Ingrédients :**\n- [ ]  1 pâte brisée\n- [ ]  80g de graines de couscous\n- [ ]  1kg de tomates rondes\n- [ ]  125g de sauce pesto (1 petit pot)\n- [ ]  200g de fromage de chèvre en bûche (soit 1 bûche)\n- [ ]  Poivre', 0, datetime.date(2023, 6, 12), datetime.datetime(2023, 6, 12, 9, 58, 9), datetime.datetime(2023, 8, 1, 18, 43, 44)),
#  (36, 'Omelette aux poivrons et chèvre', 20, 'Facile', 'Bon Marché', '/images/recipes/Omelette_poivrons_chevre.png', "***L'avis de 9 mois à croquer :***\r\n- Une recette très facile pour l'été avec des **légumes** et des **protéines.**\r\n- Le poivron est un des légu ... (72 characters truncated) ...  poivrons couvre **60% des apports recommandés en vitamine C pour la grossesse.**\r\n- Parfaite pour un **petit-déjeuner salé** ou pour un **plat** !", 4, '- Une tranche de pain complet et quelques feuilles de salade verte', "1. Bien laver les poivrons et le persil. Retirer les pépins des poivrons et les couper en lamelles.\r\n2. Chauffer une cuillère à soupe d’huile d’oli ... (336 characters truncated) ... pour que le fromage de chèvre soit bien fondu. \r\n7. Replier l’omelette et faire cuire 2 minutes sur chaque face.\r\n8. Couper en 4 et servir chaud.", '**Ingrédients :**\n- [ ]  3 poivrons (1 vert, 1 rouge, 1 jaune)\n- [ ]  8 oeufs\n- [ ]  2 cuillère à soupe d’huile d’olive\n- [ ]  *Option: 100g de bûche de chèvre*\n- [ ]  1 branche de persil (ou persil séché)\n- [ ]  Sel\n- [ ]  Poivre', 0, datetime.date(2023, 6, 15), datetime.datetime(2023, 6, 15, 15, 56, 21), datetime.datetime(2023, 6, 15, 15, 57, 8)),
#  (37, 'Clafoutis courgettes-ricotta', 45, 'Facile', 'Bon Marché', '/images/recipes/Clafoutis_courgettes_ricotta.png', "***L'avis 9 mois à croquer :***\r\n- Une recette à **petit budget** pour faire **manger des légumes à toute la famille**.\r\n- La ricotta contient **moins de graisses que les autres fromages ou que la crème fraîche**. Elle peut être utilisée dans les *gratins* ou *tarte aux légumes !*", 6, 'Une tranche de pain complet', '1. Préchauffer le four à 200°C.\r\n2. Bien laver les courgettes et les couper en rondelles.\r\n3. Faire chauffer 2 cuillères à soupe d’huile d’olive  ... (368 characters truncated) ... rser la préparation dans un plat allant au four et cuire pendant 35 minutes.\r\n10. *Option* : Râper un peu de parmesan sur le dessus avant de servir', '**Ingrédients :**\r\n- [ ]  4 courgettes moyennes (env. 600g)\r\n- [ ]  4 oeufs\r\n- [ ]  250g de ricotta (1 pot)\r\n- [ ]  40 cl de lait\r\n- [ ]  6 ... (39 characters truncated) ...  ]  2 cuillère à soupe d’huile d’olive\r\n- [ ]  Basilic (frais ou séché)\r\n- [ ]  Sel\r\n- [ ]  Poivre\r\n- [ ]  *Option* : 30g de parmesan à râper', 0, datetime.date(2023, 6, 15), datetime.datetime(2023, 6, 15, 19, 29, 35), datetime.datetime(2023, 6, 15, 19, 29, 35)),
#  (38, 'Salade de pâtes, melon, avocat, mozza et basilic', 15, 'Facile', 'Bon Marché', '/images/recipes/Melon_pates_mozza.png', "***L’avis 9 mois à croquer :*** \r\n> - Une recette équilibrée, très facile à préparer et économique pour l' **été** !\r\n> - Le **melon** et l’**avocat** sont très riches en **vitamine B9,** essentielle pour le bon développement du bébé.", 4, 'Vous pouvez ajouter une protéine en plus : **oeuf dur**, **pois chiches**, **lentilles**, ou **sardines**', '1. Faire chauffer une casserole d’eau salée jusqu’à ébullition.\r\n2. Dès que l’eau bout, ajouter les fusils crus.\r\n3. Une fois cuites, égoutter le ... (378 characters truncated) ... ouge. \r\n9. Ajouter 4 cuillères à soupe d’huile d’olive. Saler et poivrer. Mélanger.\r\n10. Servir avec des feuilles de basilic frais sur le dessus.', '**Ingrédients :**\n- [ ]  300g de fusilis crus (complets ou semi-complets si possible)\n- [ ]  2 avocats\n- [ ]  1 melon\n- [ ]  1 oignon rouge (sauf ... (79 characters truncated) ... oule ou 1 paquet de billes)\n- [ ]  3 branches de basilic frais\n- [ ]  4 c. à soupe d’huile d’olive\n- [ ]  Sel\n- [ ]  Poivre\n- [ ]  Basilic séché', 0, datetime.date(2023, 6, 18), datetime.datetime(2023, 6, 18, 16, 16, 48), datetime.datetime(2023, 8, 1, 18, 44, 55)),
# ...
#  (40, 'Salade pastèque, menthe, feta', 5, 'Facile', 'Bon Marché', '/images/recipes/Pasteque_feta.png', "***L’avis 9 mois à croquer :***\r\n- Une entrée fraîche en *moins de 5 minutes* et *économique* !\r\n- La pastèque est un fruit de saison parmi les plus **riches en eau**, un bon moyen de bien s'hydrater !", 6, "- Du riz, du boulgour ou de la semoule pour une salade complète d'été", '1. Peler la pastèque (si besoin retirer les pépins) et la couper en petits cubes dans un saladier.\r\n2. Couper la feta en cubes et les ajouter à la  ... (119 characters truncated) ... \n4. Ajouter 2 cuillères à soupe d’huile de colza. Saler (très légèrement, car la feta est déjà salée) et poivrer. Mélanger.\r\n5. Servir bien frais.', '- [ ]  1/4 de pastèque : environ 800g\r\n- [ ]  200g de feta\r\n- [ ]  3 branches de menthe fraîche\r\n- [ ]  3 cuillères à soupe d’huile de colza (pour les *omégas 3*)\r\n- [ ]  Sel\r\n- [ ]  Poivre', 0, datetime.date(2023, 6, 25), datetime.datetime(2023, 6, 25, 11, 59, 33), datetime.datetime(2023, 6, 25, 11, 59, 33)),
#  (42, 'Croquettes pommes de terre, épinards, parmesan', 40, 'Facile', 'Bon Marché', '/images/recipes/Capture d’écran 2023-07-29 à 10.11.51.png', '***L’avis 9 mois à croquer :***\n - Cette recette **végétarienne** est **économique** et **très facile à préparer**.\n- Une portion contient près de ***20% des apports recommandés en vitamine B9*** pour la grossesse.', 4, '- Une salade verte + 2 tranches de jambon ou blanc de poulet\r\n- Des épinards cuits + 1 oeuf dur', "1. Eplucher les pommes de terre et les cuire à l'eau bouillante salée pendant 25 minutes. \r\n2. Une fois cuites, écraser les pommes de terre à la fo ... (398 characters truncated) ... us forme de galettes)\r\n9. Faire chauffer 3 c. à soupe d'huile d'olive dans la poêle.\r\n10. Cuire les boulettes en les tournant pendant 10 minutes.", '**Ingrédients :**\n- [ ]  600g de pommes de terre\n- [ ]  1 oeuf\n- [ ]  1 petite boîte d’épinards en conserve (220g égoutté) ou 220g d’épinards cuits\n- [ ]  60g de parmesan\n- [ ]  3 c. à soupe d’huile d’olive \n- [ ]  Sel\n- [ ]  Poivre', 0, datetime.date(2023, 7, 29), datetime.datetime(2023, 7, 29, 8, 38, 18), datetime.datetime(2023, 8, 1, 18, 46, 24)),
#  (43, 'Potatoes de patates douce au four', 40, 'Facile', 'Bon Marché', '/images/recipes/Capture d’écran 2023-07-29 à 11.01.33.png', '***L’avis 9 mois à croquer :***\n- Une recette de potatoes **légère** car cuite au four !\n- Une portion de cette recette couvre **plus de 100% des apports en vitamine A** recommandée pour la grossesse.', 6, '- Une portion de haricots verts cuits + 1 escalope de dinde\r\n- Une portion de chou-fleur cuit + 2 oeufs durs\r\n- Une portion de mâche + 1 steak haché bien cuit', "1. Préchauffer le four à 190°C\r\n2. Brosser et bien laver sous l'eau pendant plusieurs minutes les patates douces (très important). Il ne doit surto ... (340 characters truncated) ... u four à 190°C pendant 30 minutes (en ouvrant de temps en temps le four pour laisser la vapeur s’échapper et avoir des potatoes plus croustillantes).", '**Ingrédients :**\n- [ ]  800g de patates douces (env. 3)\n- [ ]  3 c. à soupe d’huile d’olive\n- [ ]  Paprika (ou autre épice de votre choix)\n- [ ]  Thym (ou autre herbe de votre choix)\n- [ ]  Sel', 0, datetime.date(2023, 7, 29), datetime.datetime(2023, 7, 29, 9, 1, 50), datetime.datetime(2023, 8, 1, 18, 47, 10)),
#  (44, 'Barre banane-avoine', 40, 'Facile', 'Bon Marché', '/images/recipes/Barre_banane.png', '***L’avis 9 mois à croquer :***\n- Une collation sans gluten et **sans sucres ajoutés** avec simplement de la banane pour le goût.\n- Parfait pour un **goûter maison**, plus sain que des gâteaux industriels', 10, "- Un verre d'eau ou une infusion pour bien s'hydrater", "1. Préchauffer le four à 180°C\r\n2. Mettre les 2 bananes coupées en rondelles et le yaourt dans le mixeur et mixer le tout.\r\n3. Ajouter les flocon ... (302 characters truncated) ... r\n6. A la sortie du four, laisser refroidir et couper en 10 barres. Les barres se conservent dans une boîte en fer au réfrigérateur pendant 5 jours.", '**Ingrédients :**\n- [ ] 90g de flocons d’avoine\n- [ ] 2 bananes\n- [ ] 1 yaourt nature (possible végétal)\n- [ ] 2 oeufs\n- [ ] 1 c. à café de levure\n- [ ] *<u>Option*</u> : 30g de chocolat noir à 70%', 0, datetime.date(2023, 7, 29), datetime.datetime(2023, 7, 29, 12, 57, 53), datetime.datetime(2023, 8, 1, 18, 47, 41)),
#  (45, 'Galette de courgettes à la menthe', 25, 'Facile', 'Bon Marché', '/images/recipes/Galette_courgette_menthe.png', "***L’avis 9 mois à croquer :***\n- 2 galettes de courgettes = **1 portion de légumes**\n- Une recette **estivale** et **légère**, à accompagner d'une salade verte et d'une sauce au yaourt grec par exemple.", 4, "- Une sauce au yaourt grec (1 yaourt grec + jus d'1/2 citron + menthe ciselée + sel + poivre) et une salade avec des noisettes concassées\r\n- Des pois chiches (ou du houmous) et de la fêta", "1. Bien laver les courgettes et les éplucher (*si elles ne sont pas bio*). Les râper finement.\r\n2. Mettre les courgettes râpées dans un torchon et  ... (775 characters truncated) ... rées) et puis déposer dans un plat.\r\n9. Répéter l'opération jusqu'à épuisement de la pâte (*normalement environ **8 galettes** pour cette recette*)", "**Ingrédients :**\n- [ ] 4 petites courgettes (env. 600g)\n- [ ] 150 g de farine de blé (*semi-complète T80* ou *complète T110*)\n- [ ] 1/2 sachet de ... (17 characters truncated) ... n- [ ] 2 œufs\n- [ ] 3 branches de menthe fraîche (ou *2 c. à soupe si surgelée*)\n- [ ] 4 cuillères à soupe d'huile d'olive\n- [ ] Sel\n- [ ] Poivre", 0, datetime.date(2023, 8, 1), datetime.datetime(2023, 8, 1, 15, 38, 15), datetime.datetime(2023, 8, 1, 18, 48, 28)),
#  (46, 'Sardines grillées au romarin', 40, 'Facile', 'Bon Marché', '/images/recipes/Sardine_grillees.png', "***L’avis 9 mois à croquer :***\n- Il est recommandé de manger du ***poisson gras***, comme les sardines, une fois par semaine car ils sont (pratique ... (170 characters truncated) ...  Une portion de cette recette permet de couvrir **100% des apports en omega 3 (DHA et EPA) recommandés sur <u>une semaine</u>** pendant la grossesse.", 4, '- Courgettes (à griller en même temps au four ou à la plancha) + riz complet\r\n- Pommes de terre vapeur ou au four + salade verte', "1. Vider les sardines en gardant la tête (*sauter cette étape si vous avez acheté des filets*). \n2. Bien laver les sardines à l'eau froide et les sé ... (675 characters truncated) ...  minutes.<br>\n  b. **A la plancha** : mettre un peu d'huile sur la plancha, déposer les sardines alignées et faire cuire 10 minutes sur chaque face.", "**Ingrédients :**\n- [ ] 800g de sardines entières (ou 600g de filets de sardines)\n- [ ] 6 cuillères à soupe d'huile d'olive\n- [ ] 3 gousses d'ail\n- [ ] 1 citron (à presser)\n- [ ] 2 branches de romarin\n- [ ] Sel\n- [ ] Poivre", 0, datetime.date(2023, 8, 1), datetime.datetime(2023, 8, 1, 16, 35, 55), datetime.datetime(2023, 8, 1, 18, 49, 12)),
#  (48, 'Aubergines à la parmesane (version facile)', 90, 'Facile', 'Bon Marché', '/images/recipes/Aubergines_parmesane.png', "> ***L’avis 9 mois à croquer :***\n> - Une part de cette recette compte pour **2 portions de légumes**.\n> - L'ajout de parmesan et de mozzarella permet d'apporter du calcium : une portion de cette contribue à **30% des apports recommandés en calcium** pour la grossesse.", 6, '- Une salade verte + 1 tranche de pain complet (ou aux céréales ou aux noix)', "1. Préchauffer le four à 200°C. \r\n2. Laver les aubergines (vous pouvez les éplucher si elles ne sont pas bio), les couper en lamelles et les dépose ... (1027 characters truncated) ... ne, quelques tranches de mozzarella et répéter l'opération en finissant par une couche de mozzarella.\r\n8. Cuire au four pendant 30 minutes à 200°C.", "**Ingrédients :**\n- [ ] 4 aubergines (env. 1kg)\n- [ ] 1kg de tomates fraîches (ou *800g de tomates pelées en bocal ou conserve*)\n- [ ] 3 gousses d ... (23 characters truncated) ...  [ ] Origan séché\n- [ ] Basilic séché\n- [ ] 200g de mozzarella (soit une boule)\n- [ ] 100g de parmesan (à râper soi-même)\n- [ ] Sel\n- [ ] Poivre", 0, datetime.date(2023, 8, 1), datetime.datetime(2023, 8, 1, 18, 39, 4), datetime.datetime(2023, 8, 1, 18, 43, 10)),
#  (49, 'Dessert smoothie pêche-menthe', 15, 'Facile', 'Coût Moyen', '/images/recipes/Smoothie_peche_menthe.png', "> ***L’avis 9 mois à croquer :***\r\n> \r\n> - Une portion de cette recette compte pour **1 des 5 fruits et légumes par jour** \r\n> - Cette recette **sans sucres ajoutés** peut être complètement *végétale* si on utilise de la **crème à l'avoine ou à l'amande** spéciale cuisine", 4, 'Cette recette se consomme en dessert ou au petit-déjeuner.', "1. Eplucher les pêches, retirer le noyau et les couper en morceaux\n2. Bien laver les feuilles de menthe, les couper très finement (aux ciseaux)\n3.  ... (294 characters truncated) ... ver au frais avant de servir.<br><br>\n\n<u>***Remarque***</u> : Cette préparation est à consommer rapidement. Elle se conserve 24h au réfrigérateur.", "**Ingrédients :**\n- [ ]  600g de pêches\n- [ ]  2 yaourts classique (ou version végétale : 20 cl de crème d'amande ou avoine spéciale cuisine)\n- [ ]  60g de petits flocons d'avoine nature", 0, datetime.date(2023, 8, 22), datetime.datetime(2023, 8, 22, 15, 25, 31), datetime.datetime(2023, 8, 22, 15, 27, 20)),
#  (50, "Porridge d'automne à la poire", 10, 'Facile', 'Bon Marché', '/images/recipes/Porridge_poires_amandes.png', "***L'avis de 9 mois à croquer :***<br>\n- Un **petit-déjeuner complet** pour la grossesse (*les quantités les plus élevées dans la recette sont davan ... (37 characters truncated) ... sesse.*)<br>\n- Une recette **riche en fibres** (entre 30% et 40% des besoins de la grossesse) et **sans sucres ajoutés** qui cale jusqu'au déjeuner.", 1, 'Une boisson chaude : thé, infusion ou café', "1. Chauffer une casserole à feu moyen.\n2. Verser les flocons d'avoine et les faire griller à sec pendant environ 1 minute en remuant.\n3. Ajouter le ... (475 characters truncated) ... e la veille en faisant simplement tremper les flocons d'avoine dans le lait pendant toute la nuit au réfrigérateur et tout sera prêt à votre réveil !", "- [ ]  50 à 70g de flocons d'avoine (entre 5 et 7 cuillères à soupe)\n- [ ]  150 à 200ml de lait de vache ou d'amande (1 petit verre)\n- [ ]  1 poire\n- [ ]  10 amandes\n- [ ]  1/2 cuillère à café de cannelle\n- [ ]  <u>*Option*</u>: 1 cuillère à café de miel", 0, datetime.date(2023, 9, 5), datetime.datetime(2023, 9, 5, 7, 31, 14), datetime.datetime(2023, 9, 5, 7, 34, 14)),
#  (51, 'Petits muffins au maïs et aux herbes', 30, 'Facile', 'Bon Marché', '/images/recipes/Muffins_mais_persil.png', '> ***L’avis 9 mois à croquer :***\r\n> \r\n> - Une recette originale et **très facile à préparer** avec **très peu d\'ingrédients**\r\n> - Grâce au m ... (88 characters truncated) ...  la grossesse pour 2 petits muffins).\r\n> - Cette recette "du placard" est **légère** (peu de graisses et peu de sucres), **idéale pour le dîner** !', 5, '- Une salade verte + des lentilles OU\r\n- Une petite tranche de pain aux céréales + fromage frais + roquette', "1. Préchauffer le four à 180°C.\r\n2. Egoutter le maïs\r\n3. Dans un saladier, mélanger la farine, la levure, le sel et le poivre.\r\n4. Ajouter les  ... (439 characters truncated) ... son.\r\n9. Faire cuire 20 minutes. \r\n10. Les mini cakes peuvent être consommés chauds en sortant du four ou froids après une nuit au réfrigérateur.", '***Ingrédients***\n\n- [ ]  1 boîte de maïs en conserve (env. 285g égoutté)\n- [ ]  2 oeufs\n- [ ]  6 c. à soupe d’huile d’olive\n- [ ]  150 g de far ... (94 characters truncated) ...  persil frais (ou 3 c. à soupe de persil séché)\n- [ ]  1/2 sachet de levure (ou 1 c. à soupe de bicarbonate)\n- [ ]  2 pincées de sel\n- [ ]  Poivre', 0, datetime.date(2023, 9, 18), datetime.datetime(2023, 9, 18, 15, 35, 47), datetime.datetime(2023, 9, 18, 15, 36, 32)),
#  (52, 'Fondant chocolat, brocolis et crème d’amandes', 60, 'Facile', 'Bon Marché', '/images/recipes/Fondant_chocolat_brocolis.png', "***L’avis 9 mois à croquer :***\n- Un fondant au chocolat **étonnant** avec du brocoli (*vous ne le sentirez pas du tout, vous pouvez nous faire conf ... (82 characters truncated) ... ne B9 (ou folates)** à ce gâteau !\n- Une recette **très peu sucrée** et **sans beurre**, parfaite pour un **goûter gourmand** sans être trop lourd !", 10, '.', '1. Cuire les brocolis à la vapeur pendant 15 minutes.\r\n2. Mixer les brocolis cuits pour en faire une purée. \r\n3. Préchauffer le four à 180°C. \r\ ... (496 characters truncated) ... ant 10 minutes\r\n11. Mixer les amandes au robot pendant 10 minutes jusqu’à obtenir une crème. \r\n12. Verser la crème d’amandes sur le fondant cuit.', '**Ingrédients :**\n- [ ]  2 oeufs\n- [ ]  125g de chocolat noir 70%\n- [ ]  150g de brocolis (cuits à la vapeur)\n- [ ]  40g de farine\n- [ ]  1/2 c. à café de levure\n- [ ]  30g de sucre ou de miel (optionnel)\n- [ ]  1 pincée de sel\n- [ ]  70g d’amandes', 0, datetime.date(2023, 10, 10), datetime.datetime(2023, 10, 10, 7, 57, 39), datetime.datetime(2023, 10, 10, 7, 58, 37)),
#  (53, 'Brocolis sautés au sésame', 20, 'Facile', 'Bon Marché', '/images/recipes/Brocolis_sesame.png', "***L'avis 9 mois à croquer :***\r\n- Le brocoli est le légume d’hiver le plus riche en vitamine C et en vitamine B9. La cuisson à la vapeur permet de ... (24 characters truncated) ...  vitamine C. \r\n- Dans cette recette, on ajoute des graines de sésame et une sauce tahini à la pâte de sésame particulièrement riche en vitamine B9.", 4, '- Du riz *(complet ou semi-complet, si possible)* et des pois chiches\r\n- Des pâtes *(complètes ou semi-complètes, si possible)* et du blanc de poulet', "1. Laver les brocolis et couper les fleurons.\r\n2. Cuire les brocolis pendant 5 minutes à la vapeur (auto-cuiseur ou cuit-vapeur).\r\n3. Émincer l’o ... (431 characters truncated) ... illères à soupe de pâte de sésame, 2 cuillères à soupe d’eau et le jus d’un demi-citron.\r\n10. Saler légèrement et verser la sauce sur les brocolis.", '**Ingrédients :**\n- [ ] 2 brocolis\n- [ ] 1 oignon \n- [ ] 3 cuillères à soupe d’huile de sésame\n- [ ] 3 cuillères à soupe de graines de sésame \n- [ ] *Sauce tahini* : 2 cuillères à soupe de pâte de sésame, 2 cuillères à soupe d’eau, 1/2 citron.', 0, datetime.date(2023, 10, 16), datetime.datetime(2023, 10, 16, 18, 59, 34), datetime.datetime(2023, 10, 16, 19, 3, 59)),
#  (54, 'Pommes au four, à la cannelle et aux noix', 40, 'Facile', 'Bon Marché', '/images/recipes/pomme_four.png', "***L'avis 9 mois à croquer :***\r\n- Les pommes au four sont très **faciles à réaliser** et la douce odeur qui sort du four pendant la cuisson met l’ ... (53 characters truncated) ... des **noix** pour le croquant et pour les **Oméga 3** qui sont essentiels pour votre **santé cardiovasculaire** et pour le **développement du bébé**.", 4, '.', "1. Préchauffer le four à 180°C\r\n2. Laver les pommes. Si elles ne sont pas bio, il est recommandé de les éplucher.\r\n3. A l'aide d'un couteau, enle ... (261 characters truncated) ... erneaux de noix et les ajouter sur chaque pomme.\r\n8. Ajouter une pincée de cannelle sur chaque pomme.\r\n9. Faire cuire 30 minutes au four à 180°C.", '**Ingrédients :**\r\n- [ ] 4 pommes\r\n- [ ] 40g de cerneaux de noix\r\n- [ ] 20g de beurre\r\n- [ ] 4 cuillères à café de sucre complet (ou roux)\r\n- [ ] Cannelle (quantité selon vos goûts)', 0, datetime.date(2023, 10, 16), datetime.datetime(2023, 10, 16, 19, 11, 26), datetime.datetime(2023, 10, 16, 19, 11, 26))]

# %%
def search_api(query, table_choices):


    if not query:
        return print({'error': 'Aucune requête fournie.'})

    try:
        table_choices = table_choices.split(',')  # Sépare les noms de tables si plusieurs sont fournis
        all_scores = []
        for table_choice in table_choices:
            if table_choice in tables:
                table_results = search(query, data, corpus, vectorizers, table_choice)
                for score, row in table_results:
                    doc_id = get_document_id(row)
                    all_scores.append((score, row, table_choice, doc_id))
        all_scores = sorted(all_scores, key=lambda x: x[0], reverse=True)[:10]
    
        formatted_results = [{
            'score': score,
            'document_id': doc_id,
            'document': concatenate_row_values(row),
            'table': table
        } for score, row, doc_id, table in all_scores]

        return print({
            'query': query,
            'table': table_choices,
            'results': formatted_results
        })
    except Exception as e:
        return print({'error': str(e)}), 500

# %%
search('crevette', data, corpus , vectorizers , 'food')
# Out:
# [(0.5424475628741318,
#   ('25584', 'Nem aux crevettes ou crabe', 0, '/images/food/25584_nem_crevettes.png', 4, '1207')),
#  (0.5379771113923063,
#   ('25540', 'Brochette de crevettes, cuite', 0, '/images/food/25540_Brochette_crevettes.png', 44, '1202')),
#  (0.3737381091270765,
#   ('25188b', 'Risotto aux fruits de mer (crevettes, saint-jacques, etc.)', 0, '/images/food/25188b_Risotto_fruits_mer.png', 40, '1202')),
#  (0.0,
#   ('1000', 'Pastis', 0, '/images/food/2102_liqueurs_alcool_fort.png', 1, '2102')),
#  (0.0,
#   ('10000', 'Bigorneau, cuit', 0, '/images/food/10000_bigorneau_cuit.png', 18, '802')),
#  (0.0,
#   ('10001', 'Calmar ou calamar ou encornet, cru', 0, '/images/food/10001_encornet_calmar_cru.png', 19, '802')),
#  (0.0,
#   ('10002', 'Calmar ou Calamar ou encornet, a la romaine (beignet)', 0, '/images/food/10002_Beignet_calmar.png', 4, '1202')),
#  (0.0,
#   ('10003', 'Coquille Saint-Jacques, noix et corail, crue', 0, '/images/food/10003_coquille_saint_jacques_noix_corail_crue.png', 19, '802')),
#  (0.0,
#   ('10004', 'Coquille Saint-Jacques, noix et corail, cuite', 0, '/images/food/10004_coquille_saint_jacques_noix_corail_cuite.png', 18, '802')),
#  (0.0,
#   ('10005', 'Crabe, miettes, en conserve', 0, '/images/food/10005_miettes_crabe_conserve.png', 4, '802'))]
